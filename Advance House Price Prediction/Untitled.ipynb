# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
train_df=pd.read_csv('no_null_train')
test_df=pd.read_csv('no_null_test')

# %%
comb_df=pd.concat([train_df,test_df],axis=0)

# %%
comb_df.shape
# Out:
# (2919, 71)

# %%
plt.figure(figsize=(20,8))
sns.heatmap(pd.DataFrame(comb_df.corr())[20:30],annot=True)

# %%
corr_table=comb_df.corr()

# %%
corr_table=corr_table[corr_table<1]

# %%
corr_table=corr_table[corr_table>0.7]

# %%
corr_table.max()
# Out:
# MSSubClass            NaN
# LotFrontage           NaN
# LotArea               NaN
# OverallQual           NaN
# OverallCond           NaN
# YearRemodAdd          NaN
# MasVnrArea            NaN
# BsmtFinSF1            NaN
# BsmtFinSF2            NaN
# BsmtUnfSF             NaN
# TotalBsmtSF      0.801608
# 1stFlrSF         0.801608
# 2ndFlrSF              NaN
# LowQualFinSF          NaN
# GrLivArea        0.808354
# BsmtFullBath          NaN
# BsmtHalfBath          NaN
# FullBath              NaN
# HalfBath              NaN
# BedroomAbvGr          NaN
# KitchenAbvGr          NaN
# TotRmsAbvGrd     0.808354
# Fireplaces            NaN
# GarageCars       0.889686
# GarageArea       0.889686
# WoodDeckSF            NaN
# OpenPorchSF           NaN
# EnclosedPorch         NaN
# 3SsnPorch             NaN
# ScreenPorch           NaN
# PoolArea              NaN
# MiscVal               NaN
# YrSold                NaN
# dtype: float64

# %%
'TotalBsmtSF','TotRmsAbvGrd'
# Out:
# 0
